# %% [markdown]
# # Import important libraries

# %%
import os
from numpy import vectorize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# # Creat 3 text files:
# test1: hallo worled
#
#
# test2: hallo worled every day
#
#
# test3: hallo eslam
#
#
#
# test4 : i'm in Fcai Helwan university

# %%
# %%writefile test1.txt
# hallo worled
# Out:
# Overwriting test1.txt

# %%
# %%writefile test2.txt
# hallo worled every day
# Out:
# Writing test2.txt

# %%
# %%writefile test3.txt
# hallo eslam
# Out:
# Writing test3.txt

# %%
# %%writefile test4.txt
# i student at Fcai Helwan university
# Out:
# Writing test4.txt

# %% [markdown]
# # Read text files and read thier contant

# %%
sample_files = [doc for doc in os.listdir() if doc.endswith('.txt')]
sample_contents = [open(File).read() for File in sample_files]

# %% [markdown]
# # convert text file to array of numbers(vectorize)

# %%
vectorize = lambda Text: TfidfVectorizer().fit_transform(Text).toarray()

# %% [markdown]
# # compute similarity between vectors(using cosine similarity)

# %%
similarity = lambda doc1, doc2: cosine_similarity([doc1, doc2])

# %%
vectors = vectorize(sample_contents)
s_vectors = list(zip(sample_files, vectors))

# %% [markdown]
# # Creat check plagiarism function

# %%
def check_plagiarism():
    results = set()
    global s_vectors
    for sample_a, text_vector_a in s_vectors:
        new_vectors = s_vectors.copy()
        current_index = new_vectors.index((sample_a, text_vector_a))
        del new_vectors[current_index] #remove compared sample,vector
        for sample_b, text_vector_b in new_vectors:      #compare rest sample,vector
            sim_score = similarity(text_vector_a, text_vector_b)[0][1]
            sample_pair = sorted((sample_a, sample_b))
            score = sample_pair[0], sample_pair[1], sim_score
            results.add(score)
    return results

# %% [markdown]
# # print percentage of plagiarism between each pair of text files

# %%
for sample in sample_files,sample_contents:
      print(sample)
      print("/////////////////////////////////////////////////////////////////////////////////////////")
# Out:
# ['test2.txt', 'test4.txt', 'test.txt', 'test1.txt', 'test3.txt']
# /////////////////////////////////////////////////////////////////////////////////////////
# ['hallo worled every day\n', 'i student at Fcai Helwan university\n', 'Hello, this is a quick test file.\nThis is the second line of the file.\n', 'hallo worled\n', 'hallo eslam\n']
# /////////////////////////////////////////////////////////////////////////////////////////

# %%
for data in check_plagiarism():
    print(data)
# Out:
# ('file3.txt', 'file4.txt', 0.8176641207483156)
#
# ('file3.txt', 'file6.txt', 0.0)
#
# ('file1.txt', 'file4.txt', 0.0)
#
# ('file4.txt', 'file5.txt', 0.0)
#
# ('file2.txt', 'file4.txt', 0.0)
#
# ('file1.txt', 'file5.txt', 0.0)
#
# ('file2.txt', 'file3.txt', 0.0)
#
# ('file2.txt', 'file5.txt', 0.0)
#
# ('file1.txt', 'file3.txt', 0.0)
#
# ('file4.txt', 'file6.txt', 0.0)
#
# ('file3.txt', 'file5.txt', 0.0)
#
# ('file2.txt', 'file6.txt', 0.0)
#
# ('file1.txt', 'file2.txt', 0.6340862024337309)
#
# ('file1.txt', 'file6.txt', 0.0)
#
# ('file5.txt', 'file6.txt', 0.0)
